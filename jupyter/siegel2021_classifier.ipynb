# %% [markdown]
# Dictionary-based white supremacist classifier from Siegel+202
# Match dictionary, then filter out false positives with a NB classifier

# %% [markdown]
# # Dictionary

# %%
# Load white nationalist terms
import pandas as pd

words = pd.read_csv('../data/siegel2021/qjps_hatespeech_dictionary.csv')
print(len(words))
words = words[words.exclude != 'yes']
words
# Out:
# 4476
#             term                                            meaning  \
# 0      book book  in hawaii, denotes a filipino, from the allege...
# 1      book_book  in hawaii, denotes a filipino, from the allege...
# 2      book-book  in hawaii, denotes a filipino, from the allege...
# 3       bookbook  in hawaii, denotes a filipino, from the allege...
# 4      bug eater                        an person of asian descent.
# ...          ...                                                ...
# 4471  racemixing                                                NaN
# 4472   sub human                                    a black person.
# 4473   sub_human  they are said to be the missing link between a...
# 4474   sub-human  they are said to be the missing link between a...
# 4475    subhuman  they are said to be the missing link between a...
#
#                    type    source exclude
# 0            anti_asian  hatebase     NaN
# 1            anti_asian  hatebase     NaN
# 2            anti_asian  hatebase     NaN
# 3            anti_asian  hatebase     NaN
# 4            anti_asian  hatebase     NaN
# ...                 ...       ...     ...
# 4471  white nationalist       NaN     NaN
# 4472  white_nationalist  hatebase     NaN
# 4473  white_nationalist       rsd     NaN
# 4474  white_nationalist       rsd     NaN
# 4475  white_nationalist       rsd     NaN
#
# [3939 rows x 5 columns]

# %%
# Select white nationalist terms
words.type.unique()
# Out:
# array(['anti_asian', 'anti_black', 'anti_black_misogynistic',
#        'anti_immigrant', 'anti_latino', 'anti_muslim_anti_arab',
#        'anti_semitic', 'anti_semitic_white nationalist', 'anti-semitic',
#        'homophobic_anti_lbgt', 'homophobic_anti_lgbt', 'misogynistic',
#        'multiple', 'white nationalist', 'white nationalist ',
#        'white_nationalist'], dtype=object)

# %%
wn_types = ['anti_semitic_white nationalist', 'white nationalist', 'white nationalist ', 'white_nationalist']
wn_words = words[words.type.isin(wn_types)]
wn_words
# Out:
#             term                                            meaning  \
# 4013      shoaed                                                NaN
# 4128    14 words                                                NaN
# 4129    14_words                                                NaN
# 4130    14-words                                                NaN
# 4131     5 words                                                NaN
# ...          ...                                                ...
# 4471  racemixing                                                NaN
# 4472   sub human                                    a black person.
# 4473   sub_human  they are said to be the missing link between a...
# 4474   sub-human  they are said to be the missing link between a...
# 4475    subhuman  they are said to be the missing link between a...
#
#                                 type    source exclude
# 4013  anti_semitic_white nationalist    reddit     NaN
# 4128               white nationalist       adl     NaN
# 4129               white nationalist       adl     NaN
# 4130               white nationalist       adl     NaN
# 4131               white nationalist       adl     NaN
# ...                              ...       ...     ...
# 4471               white nationalist       NaN     NaN
# 4472               white_nationalist  hatebase     NaN
# 4473               white_nationalist       rsd     NaN
# 4474               white_nationalist       rsd     NaN
# 4475               white_nationalist       rsd     NaN
#
# [345 rows x 5 columns]

# %%
wn_terms = wn_words.term.unique()
len(wn_terms)
wn_terms
# Out:
# array(['shoaed', '14 words', '14_words', '14-words', '5 words', 'a c a b',
#        'a_c_ab', 'a-c-a-b', 'acab', 'akia', 'ayak', 'blood and honor',
#        'blood and soil', 'blood_and_honor', 'blood-and-honor',
#        'bloodandhonor', 'blut', 'blut und boden', 'blut und ehre',
#        'blut_und_boden', 'blut_und_ehre', 'blut-und-boden',
#        'blut-und-ehre', 'blutundboden', 'blutundehre', 'fgrn',
#        'five words', 'five_words', 'five-words', 'fivewords',
#        'for god, race and nation', 'fourteen words', 'fourteen_words',
#        'fourteen-words', 'fourteenwords', 'h s n', 'h_s_n', 'h-s-n',
#        'h.s.n.', 'hammer skins', 'hammer_skins', 'hammer-skins',
#        'hammerskins', 'hffh', 'hsn', 'itsub', 'kabark', 'kigy', 'klasp',
#        'kraft', 'krieg', 'landser', 'lotie', 'love your race',
#        'meine ehre heisst treue', 'mut', 'my honor is called loyalty',
#        'my honor is loyalty', 'my_honor_is_called_loyalty',
#        'my_honor_is_loyalty', 'my-honor-is-called-loyalty',
#        'my-honor-is-loyalty', 'myhonoriscalledloyalty',
#        'myhonorisloyalty', 'non silba sed anthar', 'non_silba_sed_anthar',
#        'non-silba-sed-anthar', 'nonsilbasedanthar',
#        'not self, but others', 'ofof', 'one front one family',
#        'one_front_one_family', 'one-front-one-family',
#        'one-front,-one-family', 'onefrontonefamily', 'orion',
#        'our race is our nation', 'our_race_is_our_nation',
#        'our-race-is-our-nation', 'ourraceisournation', 'race over all',
#        'racial holy war', 'rahowa', 'roa', 'sieg', 'sieg heil',
#        'ss bolts', 'ss_bolts', 'ss-bolts', 'ssbolts', 'stark', 'stolz',
#        'supreme white power', 'supreme white power.',
#        'supreme_white_power', 'supreme-white-power', 'supremewhitepower',
#        'swp', 'the united society of aryan skinheads',
#        'the_united_society_of_aryan_skinheads',
#        'the-united-society-of-aryan-skinheads',
#        'theunitedsocietyofaryanskinheads', 'treue',
#        'unser ehre heisst treue', 'unser_ehre_heisst_treue',
#        'unser-ehre-heisst-treue', 'unserehreheissttreue', 'usas',
#        'volksfront', 'war', 'weiss', 'weiss junge', 'weiss macht',
#        'weisser junge', 'weisser macht', 'white aryan resistance',
#        'white youth', 'white_aryan_resistance', 'white_youth',
#        'white-aryan-resistance', 'white-youth', 'whitearyanresistance',
#        'whiteyouth', 'wp', 'zionist occupied government', 'race traitor',
#        'touch of the tar brush', 'touch_of_the_tar_brush',
#        'touch-of-the-tar-brush', 'touchofthetarbrush', 'anti racist',
#        'anti white', 'anti_racist', 'anti_white', 'anti-racist',
#        'anti-white', 'antiracist', 'antiwhite', 'assimilator',
#        'auernheimer', 'degeneracy', 'degenerate', 'degenerates', 'iq gap',
#        'iq_gap', 'iq-gap', 'iqgap', 'kkkares', 'kkkonservatives',
#        'national socialism', 'national_socialism', 'national-socialism',
#        'nationalsocialism', 'think white', 'think_white', 'think-white',
#        'thinkwhite', 'white america', 'white americans', 'white nations',
#        'white population', 'white power', 'white pride', 'white race',
#        'white society', 'white us', 'white_america', 'white_americans',
#        'white_nations', 'white_population', 'white_power', 'white_pride',
#        'white_race', 'white_society', 'white_us', 'white-america',
#        'white-americans', 'white-nations', 'white-population',
#        'white-power', 'white-pride', 'white-race', 'white-society',
#        'white-us', 'whiteamerica', 'whiteamericans', 'whitenations',
#        'whitepopulation', 'whitepower', 'whitepride', 'whiterace',
#        'whitesociety', 'whiteus', 'bleached', 'caucasianally- challenged',
#        'half breed', 'half cast', 'half_breed', 'half_cast', 'half-breed',
#        'half-cast', 'halfbreed', 'halfcast', 'l b d', 'l_b_d', 'l-b-d',
#        'l.b.d.', 'lbd', 'mutt', 'o t w', 'o_t_w', 'o-t-w', 'o.t.w.',
#        'otw', 'race_traitor', 'race-traitor', 'racetraitor',
#        'racially-challanged', 'white wash', 'white_wash', 'white-wash',
#        'whitewash', 'wigg', 'wiggie', '14words', '5_words', '5-words',
#        '5words', 'animals', 'aryan', 'eternal reich', 'eternal_reich',
#        'eternal-reich', 'eternalreich', 'heil hitler', 'heil trump',
#        'heil_hitler', 'heil_trump', 'heil-hitler', 'heil-trump',
#        'heilhitler', 'heiltrump', 'kalergi', 'loveyourrace',
#        'make america white again', 'makeamericawhiteagain', 'natsoc',
#        'seig heil', 'seig_heil', 'seig-heil', 'seigheil', 'sieg_heil',
#        'sieg-heil', 'siegheil', 'stop non white privilege',
#        'stop white genocide', 'stop_non_white_privilege',
#        'stop_white_genocide', 'stop-non-white-privilege',
#        'stop-white-genocide', 'stopnonwhiteprivilege',
#        'stopwhitegenocide', 'white family', 'white values',
#        'white_family', 'white_values', 'white-family', 'white-values',
#        'whitefamily', 'whitegenocide', 'whites unite', 'whites_unite',
#        'whites-unite', 'whitesunite', 'whitevalues', 'majority_white',
#        'majority-white', 'majoritywhite', 'make_america_white_again',
#        'make-america-white-again', 'not self but others',
#        'not_self_but_others', 'not_self,_but_others',
#        'not-self-but-others', 'not-self,-but-others', 'notself,butothers',
#        'notselfbutothers', 'r o a', 'r_o_a', 'r-o-a', 'r.o.a.',
#        'race_over_all', 'race-over-all', 'raceoverall', 'racial_holy_war',
#        'racial-holy-war', 'racialholywar', 'racially challenged',
#        'racially_challenged', 'raciallychallenged', 'weiss_junge',
#        'weiss_macht', 'weiss-junge', 'weiss-macht', 'weisser_junge',
#        'weisser_macht', 'weisser-junge', 'weisser-macht', 'weisserjunge',
#        'weissermacht', 'weissjunge', 'weissmacht',
#        'zionist_occupied_government', 'zionist-occupied-government',
#        'zionistoccupiedgovernment', 'antipozi', 'mpcdot',
#        '4godraceandnation', 'for god, race, and nation',
#        'for_god_race_and_nation', 'for-god-race-and-nation',
#        'forgodraceandnation', 'race mixing', 'mongrel', 'white genocide',
#        'white_genocide', 'white-genocide', 'race_mixing', 'race-mixing',
#        'racemixing', 'sub human', 'sub_human', 'sub-human', 'subhuman'],
#       dtype=object)

# %% [markdown]
# # Train NB classifier to filter out false positives

# %%
# Load training data

trainpath = '../data/siegel2021/white_nationalist_training_data.csv'
train = pd.read_csv(trainpath, index_col=0)
train
# Out:
#                                                    text  \
# 1     RT @chipcamel: #Trump2016 fuck this gook ass t...
# 2     As long as you are going to be thinking anyway...
# 3     Psure Trump's hair was made by the CHOINAISE #...
# 4     @realDonaldTrump Trump, you're a ching chong d...
# 5     Trump finds the chink in democracy's armour.  ...
# ...                                                 ...
# 5447  Yes but the sonofabitch still has me blocked. ...
# 5448  @Bakari_Sellers chink in the armor...it's star...
# 5449  RT @xeni: Overheard at Trump rallies: "F--- th...
# 5450  RT @RaniaKhalek: Trump rallies getting worse: ...
# 5451  @sandchigger Doomed to failure: https://t.co/q...
#
#      white_nationalism_total
# 1                         no
# 2                         no
# 3                         no
# 4                         no
# 5                         no
# ...                      ...
# 5447                      no
# 5448                      no
# 5449                      no
# 5450                      no
# 5451                      no
#
# [5451 rows x 2 columns]

# %%
# Preprocess
# From appendix: "we pre-processed the data by stemming and lowercasing words, 
# and removing punctuation except for Twitter relevant symbols (@ and #)"

from nltk import word_tokenize
from nltk.stem import PorterStemmer 
from sklearn.feature_extraction.text import CountVectorizer
from string import punctuation

class StemTokenizer(object):
    def __init__(self):
        self.ps = PorterStemmer()
    def __call__(self, doc):
        return [self.ps.stem(t.lower()) for t in word_tokenize(doc)]
    
stops = list(punctuation.replace('@', '').replace('#', ''))
# print(stops)
vec = CountVectorizer(tokenizer=StemTokenizer(), stop_words=stops)

# %%
bow = vec.fit_transform(train.text)
# Out:
# /home/mamille3/white_supremacist_lang/conda_env/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['``'] not in stop_words.
#   warnings.warn(

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(bow, train.white_nationalism_total)
# Out:
# MultinomialNB()

# %%
set(sum(train.text.str.split(), []))
# Out:
# {'personally',
#  'Bomb',
#  'https://t.co/kK�ۡ��_',
#  'Nu',
#  '@NancyNvandyke86:',
#  '@spookydyke',
#  'https://t.co/uqkvPwo0yi',
#  'speaks',
#  '@racebear11:',
#  'mereka',
#  "'shoot",
#  '@2nigger4u:',
#  'grass',
#  'fukk#n',
#  '#Politics:',
#  '"absurd"',
#  "RT'd",
#  'yelled',
#  'NITA',
#  'https://t.co/6zuKwZuIKo',
#  'leader.',
#  'holds',
#  'https://t.co/JfvKo208nK',
#  'outta',
#  'berencana',
#  '@AKekelik',
#  'Seven',
#  'mfkn',
#  'send',
#  'trump?!?!?!!!!!!!',
#  'kikes,',
#  '@jhuereca2',
#  '@mjsmith23atl',
#  '@IvoryDove',
#  'route',
#  'billions',
#  'teacher',
#  'https://t.co/vsU3AISy05',
#  '!�ۡ��_',
#  'empty',
#  'troubling',
#  '#TrumpProtest',
#  "here's",
#  'won:',
#  'avi',
#  'DNC',
#  'admires',
#  '@davemeItzerW0N',
#  '#Nomorerapefugees',
#  '@jadecameron_:',
#  'technical',
#  'tourists',
#  'involved',
#  'moms',
#  'Donal�ۡ��_',
#  '6$',
#  'messican',
#  'Fallon,',
#  '"lied"',
#  '"[so]',
#  'BS�ۡ��_',
#  'nuts',
#  'Nigga',
#  'lousy',
#  'Democratic',
#  'obvious.',
#  'sabe',
#  'Nope.',
#  "'all",
#  'https://t.co/WTme0JFdVW',
#  '@bigdaddyken___',
#  'https://t.co/lG2abG6lwC',
#  'instead',
#  'https://t.co/eg73q9xxax',
#  'bandera',
#  '@crystalallclear:',
#  'C�ۡ��_',
#  '@RealTrumpfan',
#  'confession!!',
#  '"deal',
#  'armor...calls',
#  '@_johnbradburn:',
#  'broke.',
#  '#Europe�ۡ��_',
#  'possible!',
#  'impeachment:',
#  '@Inthe9thHouse',
#  'Illegals!',
#  '@AmPowerBlog',
#  '@PorningtonPost:',
#  'you,get',
#  'cisne',
#  '@julieroginsky',
#  'provide...briefings',
#  'fiddles,',
#  'Quran',
#  'shite',
#  'Corey.',
#  'restraint',
#  'invasion(legal&amp;illegal),destroy',
#  'Bunch',
#  'coon',
#  'connection',
#  'https://t.co/o2yxiXTNkz',
#  'Clay',
#  'https://t.co/jV4Jyftvs2',
#  'resigns;',
#  'https://t.co/1q5I7f7Kp2',
#  '@IntenseJingles:',
#  'https://t.co/alNRfLJZ8L',
#  'CUNT',
#  'cosa',
#  'https://t.co/IIP2gVyRAr',
#  'hat',
#  '#NeverHillary�ۡ��_',
#  '27',
#  '@Revolution41157:',
#  'aryans',
#  'https://t.co/Z23jRjfOqy',
#  'Pravda',
#  '#MyParadiseIn5Words',
#  '#NYPrimary',
#  'reuni��_n',
#  'https://t.co/G3AjZoUw9E',
#  'cousin',
#  'agreed',
#  'assault',
#  'terrifying',
#  '-Cole',
#  'sav',
#  'https://t.co/Tjc72XaBbb',
#  "niggers'",
#  'clisatan..',
#  '@JayTThomas17',
#  'polish',
#  'seguidor',
#  'penalty',
#  'Re',
#  'read?)',
#  'curb',
#  'mujer,',
#  '@tropicalthottie',
#  '1.0m',
#  'half',
#  'up!!!',
#  'fool',
#  "'remind",
#  '@laquintacolumna:',
#  '@BIRD_INKLEN:',
#  '#Wikileaks',
#  '@Ricky_Vaughn99',
#  'https://t.co/5roPkOuwy8',
#  'jumping',
#  '@micah_micahk:',
#  'TRUMP',
#  'undocumented',
#  '@huffpostqueer',
#  'Pres',
#  'mulatto',
#  'white',
#  'assaults',
#  'pos',
#  'RINOs',
#  'text',
#  'States.',
#  'ability',
#  '@lifebythecreek',
#  'leaders',
#  'voice',
#  'https://t.co/GDGSniIllI',
#  '@CarieElena',
#  'root',
#  '"Hey,',
#  '(No',
#  'them?',
#  '@sammmytx:',
#  'Third',
#  'deny',
#  'impunity,',
#  'Attack',
#  'dialogue',
#  'https://t.co/RcXmO5JTFZ',
#  'join',
#  '#CrookedHillary�ۡ��_',
#  '@arwreturns:',
#  'suddenly',
#  '@prowhitesunite:',
#  'Friday,',
#  'zone',
#  'nuts!',
#  'entering',
#  'kys',
#  'Trying',
#  'Buzzfeed',
#  '@louisnightstand',
#  'Ya...',
#  'https://t.co/Mvo2Hbr90p',
#  'petate',
#  'los̴�_negros',
#  '#SEX',
#  'trumps',
#  '"beaners"',
#  '@michaelkeyes',
#  'araby',
#  'ABC',
#  'log',
#  'fcbk',
#  'bothering..',
#  'MalyndaNyc:',
#  '#ClintonNewsNetwork',
#  'https://t.co/hqFPVuAyV8',
#  'among',
#  'Obamas',
#  'nomination!',
#  'republicano,',
#  'businessman',
#  '@StassDoll:',
#  'https://t.co/MT0xjskHOW',
#  'dinero;...',
#  "Democrats'",
#  'nigger',
#  'THEY',
#  '"You\'d',
#  'success.',
#  'qualified',
#  'unproven',
#  '"sandniggers',
#  '#Pedophiles',
#  'https://t.co/48PX7vE6eU',
#  'acero',
#  'https://t.co/KuMimEYM9q',
#  'Chieng',
#  'matando',
#  '@ThePaleoRider:',
#  '@truth2b',
#  'apoplectic',
#  'belong',
#  'trash,',
#  'Very',
#  'Ha',
#  'https://t.co/MnBj60JzGy',
#  'https://t.co/xoXfmRzY2M',
#  '"winning"',
#  'Kim',
#  'Madness:',
#  'https://t.co/mpVAAAJiNv',
#  'There',
#  'abuses',
#  'Jews.',
#  'asshole.',
#  '@MichaelCohen212',
#  '@ABC:',
#  'eating',
#  'https://t.co/3jEa0zJZrp',
#  'wie',
#  'preserve',
#  '�ۡ����#AllLivesMatter�ۡ���',
#  'alles',
#  'https://t.co/JG4hZf1ASf',
#  'https://t.co/STpnLrKdi4',
#  'Voto',
#  '@kurteichenwald:',
#  '-parents',
#  '@jaazee1:',
#  'NO,',
#  'here',
#  'Lake',
#  '@MaggieJordanACN:',
#  'buzzwords.',
#  'https://t.co/F11IBcBloP',
#  'gays!',
#  'traitors.',
#  'yesterday?',
#  'TB-coughing',
#  'https://t.co/sUWCn3mwzz',
#  'KILL',
#  'dudes.',
#  '@2ALAW:',
#  '#AltRight,',
#  'You,',
#  '@_lucassoto10',
#  'predators',
#  'much.',
#  '@michelelfrost:',
#  'bro!',
#  'eine',
#  'don�ۡ���t',
#  'showed',
#  'Followers',
#  'preoccupied',
#  '@taylorndean:',
#  '@protestona1',
#  'rabear',
#  'gun',
#  'doesn�ۡ���t',
#  'Conoce',
#  'anxiety.',
#  'SICK',
#  'https://t.co/9z5nrRa8wJ',
#  '"towel',
#  'Besides,',
#  '#Halifax',
#  '#PPSellsBodyParts',
#  '#Terrorists',
#  'NATO',
#  'https://t.co/jBmlACuIN9',
#  'world;',
#  'upsetting',
#  'uniting',
#  'terrorist.',
#  'watering',
#  'rhetoric?',
#  'PHX',
#  'kids..',
#  'NYTimes,elite',
#  'poc.',
#  'surprising.',
#  'untag',
#  'roofs,',
#  'You',
#  '@MattMurph24',
#  'Russians',
#  'faggot.',
#  'cosas',
#  'suppressing',
#  'deported"',
#  'protected',
#  '@The_RevolutionL',
#  'reality',
#  'Fox',
#  'population',
#  '#killself',
#  'wouldn�ۡ���t',
#  '@CPC_HQ',
#  '#Zionism',
#  'barrier',
#  'opinion.',
#  '@FreemarketSara:',
#  'mexicanos',
#  'stain,',
#  '@MelRJ',
#  'tol�ۡ��_',
#  'MSM!',
#  '#thugs',
#  'IN',
#  'behalf.',
#  'GRAVE',
#  '#rapefugeess',
#  '�ۡ��̏I',
#  'HILLARY',
#  'heads.....',
#  'turns',
#  '@MichaelBlackson:',
#  'angers',
#  '@CantStumpTrump1',
#  'https://t.co/ZD0R2VFGM9',
#  'whites',
#  'prominent',
#  '@DeadLovell:',
#  'hoo',
#  'force',
#  'LOOK!',
#  'refugees!',
#  'Tied',
#  '@MayorStanton',
#  'Apparently',
#  'sand',
#  'tensiones',
#  'spic',
#  '#mepolitics',
#  '@MarsHerns:',
#  '#TrumpPence16',
#  'this:',
#  '@TheBaxterBean:',
#  ';)',
#  'done.',
#  'worried.',
#  'obsessed',
#  'Sorry....the',
#  '@dave_cesario:',
#  'Islamophobe!!',
#  'https://t.co/0gcZZUSlJv',
#  'USA',
#  '^^^',
#  'https://t.co/FZO3Ck4uzZ',
#  'https://t.co/uUDHql9lIw',
#  'baby..forget',
#  'enf�ۡ��_',
#  'redouble',
#  'chambers,',
#  'Cruz:',
#  'usa,',
#  '@Bad_Sweary_Frog:',
#  '@jeffreybhess:',
#  'false',
#  'koran',
#  'Presidentcalled',
#  'musty',
#  '.@hillplus',
#  '@PatriotBrother',
#  'Clinton..',
#  '#vote',
#  '#HandCuffHillary',
#  'execution',
#  '@USCIS',
#  '(That',
#  'sapiens.',
#  'class',
#  'no.',
#  'Sul,',
#  'https://t.co/MPvt4jhc9v',
#  'America',
#  'policy',
#  'and/or',
#  'Been',
#  'KILLERY',
#  'pregant',
#  '@MyrtleBoner:',
#  'shortage',
#  'jews',
#  'also',
#  'Satire',
#  'Getty',
#  'Only',
#  'https://t.co/MBE5c70MMs�ۡ��_',
#  'https://t.co/aoxY2qXDyW',
#  'Much',
#  'Cha',
#  'sandniggers,',
#  '@DesireeAaron:',
#  'https://t.co/Aj4BuCDV48',
#  'https://t.co/Rj9GRx7ZfZ',
#  'https://t.co/qeOGOuQgRA',
#  'Galvez',
#  'goatfuckers',
#  '"Vote',
#  'mandaria',
#  'commitment!',
#  'FAVOR',
#  '#RNCinCLE',
#  'ethical',
#  'cashing',
#  'appropriated',
#  'fundraising',
#  'Insults;',
#  'posting',
#  'Elected',
#  'Full',
#  'rid',
#  'Plz',
#  'bastards',
#  'Lushsux:',
#  '@kyredblood:',
#  'gorilla"',
#  'stating',
#  'https://t.co/Q30SLAveKd',
#  '@chigger95',
#  'M�ۡ��_',
#  'tee',
#  'esquizofrenia,',
#  'realDonaldTrump',
#  '@aaytch:',
#  'sleazy',
#  'itching',
#  '@alexrileyiscool:',
#  'lunch',
#  'tweet',
#  '@Jclark427:',
#  '@MrZupa4626',
#  'morals,',
#  'worried',
#  'avowed',
#  'fatcats',
#  '@AlGiordano:',
#  'discurso',
#  '@theblaze',
#  'halla',
#  '@knobbitch:',
#  'the�ۡ��_',
#  'court',
#  'heaven',
#  '@DanielGenseric:',
#  'freaks',
#  'Beach',
#  'app�ۡ��_',
#  '#NeverTrump',
#  'smile',
#  '#blacklivesmatter',
#  'euphemism',
#  'terrorists...I',
#  '15th...',
#  "O'Donnell's",
#  '_̪����',
#  'kind',
#  '@pbump',
#  '"Having',
#  'https://t.co/WnmOL3bA7v',
#  "we'll",
#  '[kebab]',
#  'defends',
#  '@ChuckNellis',
#  'couldn�ۡ���t',
#  '#newsmokescreen',
#  'https://t.co/WxbPSLUxpp',
#  'hand:',
#  'https://t.co/3B4AyCUSSV',
#  'blij,',
#  '#conservative�ۡ��_',
#  'Shes',
#  'struck',
#  '@zRedLeaderi:',
#  'always',
#  'Gaddafi',
#  'breath...',
#  'Two',
#  'pulled',
#  'life,',
#  '@KingPolo_:',
#  'Appears',
#  'Cuz',
#  'compare?)',
#  'fault"',
#  '#LyingTrump!',
#  'risk',
#  'Who',
#  'Dole',
#  'Oops,',
#  'https://t.co/BPHSq75VxI',
#  '̴��Podr��́',
#  '@Lucasgoodman:',
#  '#ClintonKaine',
#  '@runningforpizza:',
#  '#destroy',
#  'Double',
#  'harbor',
#  'that?',
#  '@AllKnowA:',
#  '"conservative',
#  'Goodbye',
#  'Really.',
#  '@PuestoLoco:',
#  '#Operationwetback',
#  '@ktcollingwood:',
#  '_̪�_�',
#  '@Republiicunts:',
#  '#Blacklivesmatter',
#  'AKA',
#  'mocks�ۡ��_',
#  '#ILLEGALS',
#  "'I",
#  '@IsaacBarry12',
#  'apparently',
#  'cover',
#  '30-40%',
#  '@_AltRight_Anew:',
#  'https://t.co/tsNuLv9cH4',
#  'Little',
#  '#jojo_anime',
#  'appreciation.',
#  'bright',
#  '#MikeTyson',
#  'tryanny',
#  'demon',
#  'towel',
#  '@tedcruz',
#  'civilization',
#  'Foundation',
#  'aka',
#  'https://t.co/5d2DUkPczH',
#  '#bulldog',
#  '#MAGA�ۡ��_',
#  'importante,',
#  'https://t.co/U1SPx88�ۡ��_',
#  'Yea',
#  '#maga�ۡ��_',
#  'conversation',
#  'Jr.',
#  'Unsubscribed!',
#  'insults',
#  '@EntheosShines',
#  "don't",
#  '"have',
#  'muy',
#  '"niggerized"',
#  '@strombo:',
#  '#LoveTrumpsHate',
#  'perverted',
#  'https://t.co/D2olHBAZcT',
#  'Activistas',
#  '{washingtonpost}',
#  'hard.',
#  'Cronkike',
#  'armor?!',
#  'ghetto.',
#  'Ok',
#  '@KaliYugaSurf',
#  '@ShiftyTheGreen',
#  'tree:',
#  'hillary,',
#  'empinar',
#  "could've",
#  '#UnverifiedTwitterRumors',
#  'retweeted',
#  'injured',
#  'https://t.co/Owi55HV0QT',
#  'now...',
#  'classics..he',
#  '@sawmilltaters:',
#  'Pruitt',
#  'https://t.co/nOLZEHyIdz',
#  'romas,blacks,muslims',
#  'CIA',
#  'economy.',
#  'jeopardizing',
#  'https://t.co/thxQQxlaMd',
#  'https://t.co/u9pA4pRuwA',
#  'https://t.co/Gc6dgt4juy',
#  'cutting',
#  '~Donald',
#  'Sidindur',
#  'far.',
#  '_̪��__̪��__̪��_#imwithher',
#  'smack',
#  'leave',
#  'murderer',
#  'woman)',
#  'defines',
#  'SUCKING',
#  'missile',
#  'with',
#  '#BreakingNews',
#  'scam',
#  'barry',
#  '"massive',
#  'https://t.co/Jw12ungUN2',
#  '@PattyArquette',
#  '@DefendingtheUSA',
#  '@haveigotnews:',
#  'say/do',
#  'Media:',
#  'pervert!',
#  'Although',
#  'culture',
#  'Monica',
#  '@dcexaminer:',
#  'https://t.co/y2W8xBeVr3',
#  'policies',
#  '@jonasphump:',
#  'Imma',
#  'llames',
#  '$$s',
#  'watched',
#  'As',
#  'WH.',
#  'penis,',
#  '#chingchongpingpongtrumpielikeadingdong',
#  'demographically',
#  'remark:',
#  'couldnt',
#  '2endanger',
#  'Me',
#  'Casino',
#  'pandering',
#  'Triggered',
#  '1',
#  '"sluts"',
#  '@Scotty_T14',
#  '"Don\'t',
#  'Montenegro',
#  'https://t.co/vnTEnEeOWo',
#  '@POTUS',
#  'motherfucker...',
#  'charge.',
#  '"bought',
#  'guillotine,',
#  'moe.we',
#  'https://t.co/vPaIdMd16Z',
#  'B:$&amp;#',
#  'cycles',
#  '"Disabled',
#  'bus,',
#  'PREZ',
#  'temperature',
#  'Sphincter',
#  '@MerienneL:',
#  'D�ۡ��_',
#  'biz',
#  'WAPO.',
#  'https://t.co/9KcGexskdR',
#  'race.',
#  '@CNN:',
#  '@UTHornsRawk:',
#  'https://t.co/fnxZPmiUDz',
#  'it.After',
#  'chocolate....',
#  '$5',
#  '#hospital!',
#  'That',
#  '@airwreckikeman1',
#  'Mostly',
#  'tired',
#  'moolies',
#  'armor,',
#  'eventually',
#  'driving',
#  'https://t.co/54qwsb4Myz',
#  'https://t.co/TYCBGqnlME',
#  'Sarena',
#  'sort',
#  'https://t.co/x2q0zH59Be',
#  'chamber!"',
#  'Tower,',
#  '#ORPrimary',
#  '#Communist...',
#  'https://t.co/dhquaGBn8l',
#  'RT.',
#  'America�ۡ��_',
#  'Indian',
#  'conversation,',
#  'Craven',
#  'toilet',
#  'besser',
#  'actions',
#  '#XenophobesParadox',
#  'podium?',
#  'Foreign',
#  'he',
#  'https://t.co/jw6aUID�ۡ��_',
#  "Zoo's",
#  'unsafe',
#  'por',
#  'repulsive',
#  'ask,',
#  'Added',
#  'because:',
#  'communism...',
#  '@TheTab',
#  'save',
#  'battleground',
#  'https://t.co/kOz0ckAQc7',
#  '@consfession:',
#  'pruned',
#  'https://t.co/aC7dI0ZdEK',
#  'spricht',
#  '@tonyschwartz:',
#  '@panchimpanzee:',
#  'Rush',
#  '2',
#  "Germany's",
#  '#debates',
#  '-the',
#  'speaking',
#  'slap',
#  'lives?',
#  'smoothly.,nor',
#  'claro',
#  'https://t.co/DdlzyVGZbv',
#  'Not',
#  'Eddie',
#  'https:�ۡ��_',
#  'hoping',
#  'sto�ۡ��_',
#  'softening',
#  'king',
#  'Goodall',
#  'Vayan',
#  'hispanics',
#  'CEO',
#  '@natespuewell:',
#  'try',
#  'dif',
#  'thine',
#  'jeep.',
#  '-my',
#  'lady,',
#  '@RonPaul',
#  'Digit',
#  'Islamo-apologist',
#  'insane',
#  'protector',
#  '$$$',
#  'hairline',
#  'expansionist',
#  '@jtleitner',
#  '(Im',
#  '"I',
#  'Flip',
#  'Cra�ۡ��_',
#  '@granisnark12',
#  'boos',
#  'Hilarious!',
#  'bitchh',
#  '@CBSThisMorning',
#  'electorado',
#  'https://t.co/au52cUSMNR',
#  'Te�ۡ��_',
#  'dead,',
#  'CHING!',
#  'republicano...',
#  'Nazi!',
#  'https://t.co/HtKua5nEDi',
#  'Negros,',
#  'peeked',
#  '@KeithOlbermann:',
#  '@selena_volta',
#  'sponsored',
#  '@jtliteshines',
#  '1000000%',
#  'fact.',
#  '@Burger_Hall',
#  'Yorker!',
#  'neo',
#  '@randyupton33',
#  'alert!',
#  'mala',
#  '@SexiestPatriot',
#  'waterboarded',
#  'Qaeda',
#  'juong',
#  'asserted',
#  'pair',
#  '@watchup',
#  'telling',
#  'https://t.co/r�ۡ��_',
#  '#banislam?',
#  'year',
#  '"faggot',
#  'apoio',
#  '@CNNMoney',
#  '@maryann421:',
#  'crook',
#  '���_nica',
#  'educated',
#  'una',
#  'rules.',
#  'silly.',
#  '@clarissamehler:',
#  '@NetworksManager',
#  'What?',
#  '"white',
#  'et',
#  '@AlisonSpalding2:',
#  'stage?!"',
#  'https://t.co/CbKVMcpiFu',
#  'https://t.co/EHplGZA5nK',
#  'motivator',
#  'https://t.co/4nCR7sWMh0',
#  'shane',
#  'TPP,',
#  'row',
#  'want',
#  '#rape',
#  'Secret',
#  'Arab',
#  'negotia�ۡ��_',
#  'Okay--',
#  'newspaper',
#  'apology',
#  'EL',
#  'EVER',
#  'Barbara',
#  'https://t.co/TNAxThPpuW',
#  'Eleitorado',
#  'stayed',
#  '@TecTeezyBME',
#  'https://t.co/JtDTRAr4vX',
#  'Might',
#  'https://t.co/zdTIsfBMFj',
#  'repels',
#  'Melania',
#  '@willmenaker:',
#  '@TheRework:',
#  'Efter',
#  'asshat',
#  'See',
#  '@DonaldTrump',
#  'BESTSELLER',
#  'graphic',
#  'charges?',
#  '#wewuzkangz',
#  'Me:',
#  'FCN',
#  'lays',
#  'Gateway',
#  'eyebrows',
#  'promise',
#  "'e�ۡ��_",
#  'counting',
#  'Katy',
#  'AMERICANS=ARE',
#  '"spin"',
#  'took',
#  'smoke',
#  'mentioned',
#  "Him'''",
#  '5-10%',
#  'dominant',
#  '28%',
#  'herring',
#  'Inside',
#  'hostility',
#  'VP,',
#  'Finally',
#  'do.',
#  'https://t.co/KVC6IRHWyr',
#  'tactics,',
#  'animals',
#  'https://t.co/HypDhxSzPG',
#  'whining',
#  '(savage',
#  'Sorry',
#  'chamber�ۡ���',
#  'DARE',
#  'kill',
#  'Leith',
#  'Peguem',
#  'babushka_tasi:',
#  'https://t.co/TURWatr�ۡ��_',
#  '#Middlesbrough',
#  'can.',
#  'chris,',
#  "I've",
#  '#Dunwoody',
#  'ma�ۡ��_,',
#  'Carly',
#  'homo',
#  'armour',
#  'sorry',
#  '@ednajm',
#  'elite.',
#  'touch',
#  'tienen',
#  'FEMA',
#  'action',
#  '"What?!',
#  'printed',
#  '_̪��̢_̪��̢_̪��̢_̪��̢_̪��̢',
#  "pussy's",
#  'father?',
#  'unlike',
#  '@Reince',
#  'clothing',
#  'https://t.co/5e4h0RlO6b',
#  'https://t.co/8ju8AYf3u6',
#  '"quip";',
#  '#Prison4HillaryandSexualAssaulterBILL',
#  '@Jamoore02',
#  'https://t.co/iA7PXPspzB',
#  '@TheAdele:',
#  '#DinkyDonald',
#  'Preposition)',
#  'Implodes',
#  '#BERNIEorBUST',
#  'l�ۡ��_',
#  'this#Toma',
#  'deceives',
#  'asap',
#  'claim.',
#  'Attempt',
#  'infant',
#  'approval',
#  'are.',
#  'proud!fuck',
#  'touching',
#  'dissuade',
#  'fast"?',
#  'within!',
#  '#whitegenocide.If',
#  'after',
#  '@famedoII',
#  '#Bitchnigga',
#  'fi�ۡ��_',
#  'Again,',
#  'https://t.co/aFroLFQV6t',
#  'bitchhhhhh!!!!!',
#  'mess',
#  've',
#  '#deport',
#  'close',
#  'Everyone,',
#  'https://t.co/PXnbV9zrN2',
#  'truly',
#  'Badge',
#  'vince',
#  '@JellybobUK',
#  'https://t.co/4QTsJmBfG3',
#  'musulmanes,',
#  'En',
#  'zoando',
#  '@MikeRotondo86:',
#  'housing',
#  'alleged',
#  'krauthammer',
#  '???dumb',
#  'CCore',
#  'tolerant..',
#  'Define',
#  'news',
#  'truth.',
#  'working',
#  ...}
